# %% [markdown]
# png image in base64 encoding

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# jpeg image in base64 encoding

# %% [markdown]
# ![test jpeg](data:image/jpeg;base64,...)
